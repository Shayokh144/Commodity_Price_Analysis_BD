# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def getDataFrameFromCSV(filePath):
    df = pd.read_csv(filePath + '.csv')
    return df

# %%
def createPlot(dataFrame, columnName, plotTitle = "", weight = "1"):
    colValues = dataFrame[columnName]
    dateValues = dataFrame['date']
    ypoints = np.array(colValues)
    xpoints = np.array(dateValues)
    f = plt.figure()
    f.set_figwidth(12)
    f.set_figheight(6)
    plt.plot(xpoints, ypoints, color='green')
    plt.title(plotTitle+ "\n unit:"+ weight)
    plt.xlabel("days")
    plt.ylabel("price")
    plt.show()

# %%
df = getDataFrameFromCSV('../../data/price_data/chicken/chicken')

# %%
print("Sample Data:")
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')
print(df.head(10))
# Out:
# Sample Data:
#                                         product_name weight_raw  weight_value  \
# 0                   Broiler Chicken Skin Off ± 50 gm       1 kg             1
# 1                      Cock Chicken Skin Off ± 25 gm     500 gm           500
# 2                              Roast Chicken ± 10 gm     275 gm           275
# 3                    Broiler Chicken Skin On ± 50 gm       1 kg             1
# 4        Bengal Meat Whole Chicken Curry Cut ± 50 gm       1 kg             1
# 5                                        Pigeon Meat       each             1
# 6               Whole Deshi Chicken Skin Off ± 25 gm     500 gm           500
# 7                  Whole Deshi Duck (Hash) With Skin     900 gm           900
# 8                          Chicken Liver Gizzard Mix       1 kg             1
# 9  Whole Layer Chicken Skin Off (Net Weight ± 50 gm)     800 gm           800
#
#   weight_unit price_raw  price discount_price_raw  discount_price       date  \
# 0          kg     ৳ 335    335              ৳ 325           325.0 2022-10-26
# 1          gm     ৳ 314    314              ৳ 309           309.0 2022-10-26
# 2          gm     ৳ 200    200              ৳ 179           179.0 2022-10-26
# 3          kg     ৳ 299    299              ৳ 279           279.0 2022-10-26
# 4          kg     ৳ 350    350                NaN             NaN 2022-10-26
# 5        each     ৳ 169    169              ৳ 159           159.0 2022-10-26
# 6          gm     ৳ 475    475              ৳ 465           465.0 2022-10-26
# 7          gm     ৳ 549    549              ৳ 509           509.0 2022-10-26
# 8          kg     ৳ 249    249              ৳ 229           229.0 2022-10-26
# 9          gm     ৳ 529    529              ৳ 459           459.0 2022-10-26
#
#        time
# 0  12:22:09
# 1  12:22:09
# 2  12:22:09
# 3  12:22:09
# 4  12:22:09
# 5  12:22:09
# 6  12:22:09
# 7  12:22:09
# 8  12:22:09
# 9  12:22:09

# %%
# convert Cock Chicken Skin Off 500 gm to 1 kg
condition = (df['product_name'] == 'Cock Chicken Skin Off ± 25 gm') & (df['weight_value'] == 500)
df.loc[condition,'price'] = df['price'] * 2
df.loc[condition,'weight_value'] = df['weight_value'] * 2

# %%
def showLineGraph(dataFrame, item, weight, weightRaw):
    df = dataFrame
    itemName = item
    filteredDf = df.loc[(df.product_name == itemName) & (df.weight_value == weight)]
    createPlot(filteredDf, 'price', itemName, weightRaw)

# %%
showLineGraph(df, "Broiler Chicken Skin Off ± 50 gm", 1, "1 kg")

# %%
showLineGraph(df, "Cock Chicken Skin Off ± 25 gm", 1000, "1 kg")

# %%
def createMultilinePlot(dataFrames, columnNames, plotTitle = "", weight = "1", lineNames = []):
    f = plt.figure()
    f.set_figwidth(8)
    f.set_figheight(4)
    i = 0
    colors = ['green', 'blue']
    for dataFrame, columnName in zip(dataFrames, columnNames):
        #dataFrame.head(3)
        colValues = dataFrame[columnName]
        dateValues = dataFrame['date']
        ypoints = np.array(colValues)
        xpoints = np.array(dateValues)
        plt.plot(xpoints, ypoints, color=colors[i], label=lineNames[i])
        i += 1
        i %= 2
    #plt.title(plotTitle+ "\n unit:"+ weight)
    plt.xlabel("days")
    plt.ylabel("price BDT")
    plt.title("unit 1 kg")
    plt.legend(loc='best')
    plt.show()

# %%
def showMultipleLineGraph(dataFrame, items, weights, weightRaws):
    filteredDfs = []
    itemNames = []
    df = dataFrame
    for itemName, weight in zip(items,weights):
        itemNames.append(itemName)
        filteredDf = df.loc[(df.product_name == itemName) & (df.weight_value == weight)]
        filteredDfs.append(filteredDf)
    createMultilinePlot(filteredDfs, ['price','price'], itemNames, weightRaws, items)

# %%
items = ["Broiler Chicken Skin Off ± 50 gm", "Cock Chicken Skin Off ± 25 gm"]
showMultipleLineGraph(df, items, [1,1000], [ "1 kg","500 gm"])
